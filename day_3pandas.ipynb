# %%
import pandas as pd
df = pd.DataFrame({'Name':['Ali', 'Sara', 'Ahmad', 'Zain'], 'Score': [88, 92, 79, 95]})

# %%
df
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.head()
df['Score'].mean()
# Out:
# np.float64(88.5)

# %%
df[df['Score'] > 90]
# Out:
#    Name  Score
# 1  Sara     92
# 3  Zain     95

# %%
df['Grade'] = ['A', 'A+', 'B', 'A']
df
# Out:
#     Name  Score Grade
# 0    Ali     88     A
# 1   Sara     92    A+
# 2  Ahmad     79     B
# 3   Zain     95     A

# %%
df.plot(kind='bar', x='Name', y='Score')
df
# Out:
#     Name  Score Grade
# 0    Ali     88     A
# 1   Sara     92    A+
# 2  Ahmad     79     B
# 3   Zain     95     A

# %%
df['Score'].max()
# Out:
# 95

# %%
df['Pass'] = df ['Score']>85

# %%
df
# Out:
#     Name  Score Grade   Pass
# 0    Ali     88     A   True
# 1   Sara     92    A+   True
# 2  Ahmad     79     B  False
# 3   Zain     95     A   True

# %%
df[df['Pass']]
# Out:
#    Name  Score Grade  Pass
# 0   Ali     88     A  True
# 1  Sara     92    A+  True
# 3  Zain     95     A  True

# %%
df.to_cvs('my_students.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_cvs('my_students.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.DataFrame({'Name':['Ali', 'Sara', 'Ahmad', 'Zain'], 'Score': [88, 92, 79, 95]})

# %%
df.to_cvs('my_students.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6896\3924781937.py in ?()
# ----> 1 df.to_cvs('my_students.csv', index=False)
#
# C:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_cvs'

# %%
df.to_csv('my_students.csv', index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SALMAN COMPUTERS'

# %%
pd.read_csv('my_students.csv')
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.shape
# Out:
# (4, 2)

# %%
df.columns
# Out:
# Index(['Name', 'Score'], dtype='object')

# %%
df.describe()
# Out:
#            Score
# count   4.000000
# mean   88.500000
# std     6.952218
# min    79.000000
# 25%    85.750000
# 50%    90.000000
# 75%    92.750000
# max    95.000000

# %%
df['Name']
# Out:
# 0      Ali
# 1     Sara
# 2    Ahmad
# 3     Zain
# Name: Name, dtype: object

# %%
df['Score']
# Out:
# 0    88
# 1    92
# 2    79
# 3    95
# Name: Score, dtype: int64

# %%
df[['Name', 'Score']]
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df[['Name', 'Score']]
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
data = {'Name': ['Ali', 'Sara', 'Ahmad', 'Zain'],
        'Score': [88, 92, 79, 95]}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.tail()
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.head(2)
# Out:
#    Name  Score
# 0   Ali     88
# 1  Sara     92

# %%
df.tail(1)
# Out:
#    Name  Score
# 3  Zain     95

# %%
df.head(10)
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.shape
# Out:
# (4, 2)

# %%
df.shape[0]
# Out:
# 4

# %%
df.shape[1]
# Out:
# 2

# %%
import pandas as pd
pd.DataFrame(data)
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df = pd.DataFrame(data)

# %%
df['Name']
# Out:
# 0      Ali
# 1     Sara
# 2    Ahmad
# 3     Zain
# Name: Name, dtype: object

# %%
df['Score']
# Out:
# 0    88
# 1    92
# 2    79
# 3    95
# Name: Score, dtype: int64

# %%
df[['Name' , 'Score']]
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.head()
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.tail()
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.shape
# Out:
# (4, 2)

# %%
df.head()
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.tail()
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79
# 3   Zain     95

# %%
df.shape[0]
# Out:
# 4

# %%
df = pd.concat([df, pd.DataFrame({'Name': ['Muhammad Tariq'], 'Score':[100]})], ignore_index=True)
df.tail(2)
# Out:
#              Name  Score
# 3            Zain     95
# 4  Muhammad Tariq    100

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
data = {'Name': ['Ali', 'Sara', 'Ahmad', 'Zain'],
        'Score': [88, 92, 79, 95]}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 data = {'Name': ['Ali', 'Sara', 'Ahmad', 'Zain'],
#       2         'Score': [88, 92, 79, 95]}
# ----> 3 df = pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
data = {'Name': ['Ali', 'Sara', 'Ahmad', 'Zain'],
        'Score': [88, 92, 79, 95]}
df = pd.DataFrame(data)

# %%
df = pd.concat([df, pd.DataFrame({'Name': ['Muhammad Tariq'], 'Score':[100]})], ignore_index=True)
df.tail(2)
# Out:
#              Name  Score
# 3            Zain     95
# 4  Muhammad Tariq    100

# %%
len(df)
# Out:
# 5

# %%
df.head(3)
# Out:
#     Name  Score
# 0    Ali     88
# 1   Sara     92
# 2  Ahmad     79

# %%
print("Total rows:", len(df))
# Out:
# Total rows: 5

# %%
print("Columns:", df.columns)
# Out:
# Columns: Index(['Name', 'Score'], dtype='object')

# %%
print(df.head())
# Out:
#              Name  Score
# 0             Ali     88
# 1            Sara     92
# 2           Ahmad     79
# 3            Zain     95
# 4  Muhammad Tariq    100

# %%
df[df['Score']>90]
# Out:
#              Name  Score
# 1            Sara     92
# 3            Zain     95
# 4  Muhammad Tariq    100

# %%
df[df['Score']<90]
# Out:
#     Name  Score
# 0    Ali     88
# 2  Ahmad     79

# %%
df.sort_values('Score', ascending=False)
# Out:
#              Name  Score
# 4  Muhammad Tariq    100
# 3            Zain     95
# 1            Sara     92
# 0             Ali     88
# 2           Ahmad     79

# %%
df.sort_values('Score', ascending=True)
# Out:
#              Name  Score
# 2           Ahmad     79
# 0             Ali     88
# 1            Sara     92
# 3            Zain     95
# 4  Muhammad Tariq    100
